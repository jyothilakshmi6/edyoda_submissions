# %%
import datetime
history = {}

class Account(object):
    def __init__(self):
        self.pin = 1234
        self.balance = 0

    def checkCode(self,value):
        return self.pin == value

    def checkBalance(self):
        print ('Current balance is ' + str(self.balance) + ' rupees.')

    def checkTransactions(self):
        print('Previous transactions:')
        for item in sorted(history):
            print (item + '\t\t' + str(history[item]) + ' rupees.')

    def withdraw(self, pin, value):
        if self.checkCode(pin):
            if value <= self.balance:
                currentTime = datetime.datetime.now()
                history[str(currentTime)] = -value
                self.balance -= value
                print ('Successfully withdrawn ' + str(value) + ' rupees from your account.')
            else:
                print ('Not enough balance.')
        else:
            print ('Wrong pin code. Try again.')

    def deposit(self, pin, value):
        if self.checkCode(pin):
            self.balance += value
            history[str(datetime.datetime.now())] = value
            print ('Successfully deposited ' + str(value) + ' rupees from your account.')
        else:
            print ('Wrong pin code. Try again.')

    def createMBNet(self, value):
        import random
        self.MBalance = value
        print ('You have Successfully created an MBNet card with ' + str(self.MBalance) + ' rupees.')
        card_ID = [random.randint(0, 9) for _ in range(23)]
        print ('Your card id is ' + "".join(str(id) for id in card_ID))
        card_secret = [random.randint(0, 9) for _ in range(4)]
        print ('Your secret code is ' + "".join(str(secret) for secret in card_secret))

    def changePIN(self, oldvalue, newvalue):
        if self.checkCode(oldvalue):
            self.pin = newvalue
            print ('Pin code has been successfully changed.')
        else:
            print ('Wrong pin code. Try again.')


class CheckingAccount(Account):
    def __init__(self):
        super().__init__()
        self.balance = 12000


class SavingsAccount(Account):
    def __init__(self):
        super().__init__()
        self.balance = 5000
    

class BusinessAccount(Account):
    def __init__(self):
        super().__init__()
        self.balance = 10000

checksAcc = CheckingAccount()
print ('Enter pin:')
pin = input()
if checksAcc.checkCode(int(pin)):
    checksAcc.withdraw(1234,4000)
    checksAcc.deposit(1234,22000)
    checksAcc.withdraw(1234,22000)
    checksAcc.deposit(1234,24000)
    checksAcc.withdraw(1234,2000)
    checksAcc.deposit(1234,1000)
    checksAcc.withdraw(1234,2000)
    checksAcc.deposit(1234,9000)
checksAcc.checkTransactions()
checksAcc.checkBalance()
myAcc = SavingsAccount()
hisAcc = BusinessAccount()
checksAcc.createMBNet(500)
checksAcc.changePIN(1234, 5678)
# Out:
# Enter pin:
# 1234
# Successfully withdrawn 4000 rupees from your account.
# Successfully deposited 22000 rupees from your account.
# Successfully withdrawn 22000 rupees from your account.
# Successfully deposited 24000 rupees from your account.
# Successfully withdrawn 2000 rupees from your account.
# Successfully deposited 1000 rupees from your account.
# Successfully withdrawn 2000 rupees from your account.
# Successfully deposited 9000 rupees from your account.
# Previous transactions:
# 2023-04-06 19:28:40.147106		9000 rupees.
# Current balance is 38000 rupees.
# You have Successfully created an MBNet card with 500 rupees.
# Your card id is 62391646933720975585678
# Your secret code is 7889
# Pin code has been successfully changed.
